# %%
# !git clone https://github.com/DepthAnything/Depth-Anything-V2
# !mv Depth-Anything-V2 Depth_Anything_V2
# Out:
# Cloning into 'Depth-Anything-V2'...
# remote: Enumerating objects: 142, done.
# remote: Total 142 (delta 0), reused 0 (delta 0), pack-reused 142 (from 1)
# Receiving objects: 100% (142/142), 45.17 MiB | 10.85 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# %pip install OpenEXR numpy matplotlib imageio
# Out:
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.5 MB/s eta 0:00:00a 0:00:01
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Small/resolve/main/depth_anything_v2_metric_vkitti_vits.pth?download=true -O depth_anything_v2_metric_vkitti_vits.pth
# Out:
# --2025-05-10 08:59:32--  https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Small/resolve/main/depth_anything_v2_metric_vkitti_vits.pth?download=true
# Resolving huggingface.co (huggingface.co)... 18.172.134.24, 18.172.134.88, 18.172.134.124, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.24|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Base/resolve/main/depth_anything_v2_metric_vkitti_vitb.pth?download=true -O depth_anything_v2_metric_vkitti_vitb.pth
# Out:
# --2025-05-10 08:59:34--  https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Base/resolve/main/depth_anything_v2_metric_vkitti_vitb.pth?download=true
# Resolving huggingface.co (huggingface.co)... 18.172.134.124, 18.172.134.4, 18.172.134.24, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Large/resolve/main/depth_anything_v2_metric_vkitti_vitl.pth?download=true -O depth_anything_v2_metric_vkitti_vitl.pth
# Out:
# --2025-05-10 08:59:39--  https://huggingface.co/depth-anything/Depth-Anything-V2-Metric-VKITTI-Large/resolve/main/depth_anything_v2_metric_vkitti_vitl.pth?download=true
# Resolving huggingface.co (huggingface.co)... 18.172.134.24, 18.172.134.4, 18.172.134.124, ...
# Connecting to huggingface.co (huggingface.co)|18.172.134.24|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://upload.wikimedia.org/wikipedia/commons/e/e7/Everest_North_Face_toward_Base_Camp_Tibet_Luca_Galuzzi_2006.jpg -O mountains.jpg
# Out:
# --2025-05-10 10:52:04--  https://upload.wikimedia.org/wikipedia/commons/e/e7/Everest_North_Face_toward_Base_Camp_Tibet_Luca_Galuzzi_2006.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 903706 (883K) [image/jpeg]
# Saving to: ‘mountains.jpg’
#
# mountains.jpg       100%[===================>] 882.53K  --.-KB/s    in 0.1s
#
# 2025-05-10 10:52:05 (5.82 MB/s) - ‘mountains.jpg’ saved [903706/903706]

# %%
# !mkdir -p datasets/city-walking/images
# !mkdir -p datasets/city-walking/depths

# %%
# !wget https://u355171-sub1:m4DDxuwJzm3Fy9vn@u355171-sub1.your-storagebox.de/city-walking.zip -O datasets/city-walking.zip
# Out:
# --2025-05-12 18:52:09--  https://u355171-sub1:*password*@u355171-sub1.your-storagebox.de/city-walking.zip
# Resolving u355171-sub1.your-storagebox.de (u355171-sub1.your-storagebox.de)... 46.4.186.239, 2a01:4f8:2b03:b0f::2
# Connecting to u355171-sub1.your-storagebox.de (u355171-sub1.your-storagebox.de)|46.4.186.239|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="WebDAV Restricted"
# Reusing existing connection to u355171-sub1.your-storagebox.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 771173176 (735M) [application/zip]
# Saving to: ‘datasets/city-walking.zip’
#
# datasets/city-walki 100%[===================>] 735,45M  5,18MB/s    in 3m 9s
#
# 2025-05-12 18:55:18 (3,90 MB/s) - ‘datasets/city-walking.zip’ saved [771173176/771173176]

# %%
# !wget https://u355171-sub1:m4DDxuwJzm3Fy9vn@u355171-sub1.your-storagebox.de/city-walking-depth.zip -O datasets/city-walking-depth.zip
# Out:
# --2025-05-12 18:55:35--  https://u355171-sub1:*password*@u355171-sub1.your-storagebox.de/city-walking-depth.zip
# Resolving u355171-sub1.your-storagebox.de (u355171-sub1.your-storagebox.de)...
# 46.4.186.239, 2a01:4f8:2b03:b0f::2
# Connecting to u355171-sub1.your-storagebox.de (u355171-sub1.your-storagebox.de)|46.4.186.239|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
# Authentication selected: Basic realm="WebDAV Restricted"
# Reusing existing connection to u355171-sub1.your-storagebox.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 207033089 (197M) [application/zip]
# Saving to: ‘datasets/city-walking-depth.zip’
#
# datasets/city-walki 100%[===================>] 197,44M  4,74MB/s    in 54s
#
# 2025-05-12 18:56:30 (3,65 MB/s) - ‘datasets/city-walking-depth.zip’ saved [207033089/207033089]

# %%
# !unzip -q datasets/city-walking-depth.zip -d datasets/city-walking/depths

# %%
# !unzip -q datasets/city-walking.zip -d datasets/city-walking/images

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib
import matplotlib.cm
import pandas as pd
import matplotlib.pyplot as plt

import OpenEXR
import Imath

from PIL import Image
from IPython.display import display
from tqdm.notebook import tqdm
from torch.utils.data import Dataset
from pathlib import Path
from typing import Callable
from Depth_Anything_V2.metric_depth.depth_anything_v2.dpt import DepthAnythingV2
# Out:
# xFormers not available
# xFormers not available

# %%
def colorize(
    value: torch.Tensor | np.ndarray,
    vmin: float | None = None,
    vmax: float | None = None,
    cmap: str = "magma_r",
    invalid_val: float = -99,
    invalid_mask: np.ndarray | None = None,
    background_color: tuple[int, int, int, int] = (128, 128, 128, 255),
    gamma_corrected: bool = False,
    value_transform: Callable[[np.ndarray], np.ndarray] | None = None,
) -> np.ndarray:
    """Converts a depth map to a color image.

    Args:
        value (torch.Tensor, numpy.ndarray): Input depth map. Shape: (H, W) or (1, H, W) or (1, 1, H, W). All singular dimensions are squeezed
        vmin (float, optional): vmin-valued entries are mapped to start color of cmap. If None, value.min() is used. Defaults to None.
        vmax (float, optional):  vmax-valued entries are mapped to end color of cmap. If None, value.max() is used. Defaults to None.
        cmap (str, optional): matplotlib colormap to use. Defaults to 'magma_r'.
        invalid_val (int, optional): Specifies value of invalid pixels that should be colored as 'background_color'. Defaults to -99.
        invalid_mask (numpy.ndarray, optional): Boolean mask for invalid regions. Defaults to None.
        background_color (tuple[int], optional): 4-tuple RGB color to give to invalid pixels. Defaults to (128, 128, 128, 255).
        gamma_corrected (bool, optional): Apply gamma correction to colored image. Defaults to False.
        value_transform (Callable, optional): Apply transform function to valid pixels before coloring. Defaults to None.

    Returns:
        numpy.ndarray, dtype - uint8: Colored depth map. Shape: (H, W, 4)
    """
    if isinstance(value, torch.Tensor):
        value = value.detach().cpu().numpy()

    value = value.squeeze()
    if invalid_mask is None:
        invalid_mask = value == invalid_val
    mask = np.logical_not(invalid_mask)

    # normalize
    vmin = np.percentile(value[mask], 2) if vmin is None else vmin
    vmax = np.percentile(value[mask], 85) if vmax is None else vmax
    if vmin != vmax:
        value = (value - vmin) / (vmax - vmin)  # vmin..vmax
    else:
        # Avoid 0-division
        value = value * 0.0

    # squeeze last dim if it exists
    # grey out the invalid values

    value[invalid_mask] = np.nan
    cmapper = matplotlib.colormaps[cmap]
    if value_transform:
        value = value_transform(value)
        # value = value / value.max()
    value = cmapper(value, bytes=True)  # (n x m x4)

    # img = value[:, :, :]
    img = value[...]
    img[invalid_mask] = background_color

    #     return img.transpose((2, 0, 1))
    if gamma_corrected:
        # gamma correction
        img = img / 255
        img = np.power(img, 2.2)
        img = img * 255
        img = img.astype(np.uint8)
    return img

# %%
DEVICE = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

model_configs = {
    'vits': {'encoder': 'vits', 'features': 64, 'out_channels': [48, 96, 192, 384]},
    'vitb': {'encoder': 'vitb', 'features': 128, 'out_channels': [96, 192, 384, 768]},
    'vitl': {'encoder': 'vitl', 'features': 256, 'out_channels': [256, 512, 1024, 1024]}
}
encoder = 'vits' # or 'vits', 'vitb'
dataset = 'vkitti' # 'hypersim' for indoor model, 'vkitti' for outdoor model
max_depth = 16.8 # 20 for indoor model, 80 for outdoor model
min_depth = 0.001

model_small = DepthAnythingV2(**model_configs[encoder], max_depth=max_depth)
model_small.load_state_dict(
    torch.load(
        f"depth_anything_v2_metric_{dataset}_{encoder}.pth",
        map_location="cpu",
        weights_only=True,
    ),
)
model_small.to(DEVICE)
model_small.eval()
# Out:
# DepthAnythingV2(
#   (pretrained): DinoVisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 384, kernel_size=(14, 14), stride=(14, 14))
#       (norm): Identity()
#     )
#     (blocks): ModuleList(
#       (0-11): 12 x NestedTensorBlock(
#         (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (attn): MemEffAttention(
#           (qkv): Linear(in_features=384, out_features=1152, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=384, out_features=384, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): LayerScale()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=384, out_features=1536, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=1536, out_features=384, bias=True)
# ...

# %%
image = Image.open("datasets/city-walking/images/00001-bl-image.png")

# %%
display(image.resize((512, 512)))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
model_small.eval()
pred = model_small.infer_image(np.ascontiguousarray(image))

# %%
depth_img = Image.fromarray(colorize(pred))
display(depth_img.resize((512, 512)))
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %%
def read_ken_burns_depth(exr_path: str) -> np.ndarray:
    """Properly reads depth maps from 3D-Ken-Burns dataset"""
    exr_file = OpenEXR.InputFile(exr_path)
    dw = exr_file.header()['dataWindow']
    size = (dw.max.x - dw.min.x + 1, dw.max.y - dw.min.y + 1)

    # Try different channel names - the dataset sometimes uses 'Y' or 'A' for depth
    for channel in ['Y', 'A', 'R', 'G', 'B']:
        try:
            pt = Imath.PixelType(Imath.PixelType.FLOAT)
            depth_str = exr_file.channel(channel, pt)
            depth = np.frombuffer(depth_str, dtype=np.float32)
            depth = depth.reshape((size[1], size[0]))
            depth = depth / 255.0
            return depth
        except:
            continue

# Read the depth map
depth_map = read_ken_burns_depth("datasets/city-walking/depths/00001-bl-depth.exr")

# Visualize
depth_img = Image.fromarray(colorize(depth_map))
display(depth_img.resize((512, 512)))

# Print depth info
print(f"Depth map shape: {depth_map.shape}")
print(f"Depth range: {np.min(depth_map):.2f} to {np.max(depth_map):.2f}")
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>
# Depth map shape: (512, 512)
# Depth range: 0.56 to 256.00

# %%
KEN_BURNS_DATASET_PATH = Path("datasets/city-walking")

# %%
class KenBurnsDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir: Path, transform: Callable | None = None) -> None:
        self.root_dir = root_dir
        self.transform = transform
        self.samples = self._load_samples()

    def _load_samples(self) -> list[tuple[Path, Path]]:
        # Предполагаемая структура: root_dir/images/ и root_dir/depths/
        image_files = [i for i in (self.root_dir / "images").iterdir() if i.suffix == ".png"]
        depth_files = []
        for image in image_files:
            img_id, cam_pos, _ = image.stem.split("-")
            if not (self.root_dir / "depths" / f"{img_id}-{cam_pos}-depth.exr").exists():
                raise FileNotFoundError(f"Depth file not found for image {image}")
            depth_files.append(self.root_dir / "depths" / f"{img_id}-{cam_pos}-depth.exr")
        return list(zip(image_files, depth_files))

    def __len__(self) -> int:
        return len(self.samples)

    def __getitem__(self, idx: int) -> tuple[str, np.ndarray, np.ndarray]:
        image_path, depth_path = self.samples[idx]

        image = np.ascontiguousarray(Image.open(image_path))  # Функция уже реализована в ноутбуке
        depth = read_ken_burns_depth(depth_path.as_posix())  # Тоже должна быть готова, иначе напишем свою

        if self.transform:
            image = self.transform(image)

        # Преобразование глубины, если нужно (например, нормализация, приведение к float32)
        depth = self._process_depth(depth)

        return image_path.name, image, depth

    def _process_depth(self, depth: np.ndarray) -> np.ndarray:
        # Привести к нужному масштабу, например:
        return depth.astype(np.float32)

# %%
selection_dataset = KenBurnsDataset(root_dir=KEN_BURNS_DATASET_PATH)

# %%
name, image, depth = selection_dataset[148]
name, image.shape, depth.shape
# Out:
# ('00338-tl-image.png', (512, 512, 3), (512, 512))

# %%
def eval_depth(pred: torch.Tensor, target: torch.Tensor) -> dict[str, float]:
    assert pred.shape == target.shape

    thresh = torch.max((target / pred), (pred / target))

    d1 = torch.sum(thresh < 1.25).float() / len(thresh)
    d2 = torch.sum(thresh < 1.25 ** 2).float() / len(thresh)
    d3 = torch.sum(thresh < 1.25 ** 3).float() / len(thresh)

    diff = pred - target
    diff_log = torch.log(pred) - torch.log(target)

    abs_rel = torch.mean(torch.abs(diff) / target)
    sq_rel = torch.mean(torch.pow(diff, 2) / target)

    rmse = torch.sqrt(torch.mean(torch.pow(diff, 2)))
    rmse_log = torch.sqrt(torch.mean(torch.pow(diff_log , 2)))

    log10 = torch.mean(torch.abs(torch.log10(pred) - torch.log10(target)))
    silog = torch.sqrt(torch.pow(diff_log, 2).mean() - 0.5 * torch.pow(diff_log.mean(), 2))

    return {'d1': d1.item(), 'd2': d2.item(), 'd3': d3.item(), 'abs_rel': abs_rel.item(), 'sq_rel': sq_rel.item(),
            'rmse': rmse.item(), 'rmse_log': rmse_log.item(), 'log10':log10.item(), 'silog':silog.item()}

# %%
idx = 12
_, img, true_depth = selection_dataset[idx]

with torch.no_grad():
    pred = model_small.infer_image(img)
    pred = torch.from_numpy(pred)

true_depth = torch.from_numpy(true_depth)
mask = (true_depth >= min_depth) & (true_depth <= max_depth)

eval_depth(pred[mask], true_depth[mask])
# Out:
# {'d1': 0.050575125962495804,
#  'd2': 0.09393943101167679,
#  'd3': 0.989484965801239,
#  'abs_rel': 0.6408080458641052,
#  'sq_rel': 1.228451132774353,
#  'rmse': 2.5523884296417236,
#  'rmse_log': 0.5011916756629944,
#  'log10': 0.2130192369222641,
#  'silog': 0.3629363775253296}

# %%
Image.fromarray(img.astype("uint8"))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
depth_colorized = colorize(pred)
Image.fromarray(depth_colorized.astype("uint8"))
# Out:
# <PIL.Image.Image image mode=RGBA size=512x512>

# %%
def evaluate_model(model: nn.Module, dataset: KenBurnsDataset) -> pd.DataFrame:
    metrics = []

    for path_to, img, true_depth in tqdm(
        selection_dataset, total=len(selection_dataset)
    ):
        with torch.no_grad():
            pred = model.infer_image(img)
            pred = torch.from_numpy(pred)

        true_depth = torch.from_numpy(true_depth)
        mask = (true_depth >= min_depth) & (true_depth <= max_depth)

        metrics.append({"name": path_to, **eval_depth(pred[mask], true_depth[mask])})

    return pd.DataFrame(metrics)

# %%
metrics = evaluate_model(model_small, selection_dataset)
metrics.head()
# Out:
#   0%|          | 0/2768 [00:00<?, ?it/s]
#                  name        d1        d2        d3   abs_rel    sq_rel  \
# 0  00120-br-image.png  0.064842  0.315434  0.610322  0.668236  1.731255
# 1  00443-br-image.png  0.352949  0.933867  0.986956  0.319270  0.399391
# 2  00685-br-image.png  0.028476  0.076490  0.790152  0.828265  1.473561
# 3  00100-br-image.png  0.119964  0.806455  0.990515  0.407345  0.610524
# 4  00345-tr-image.png  0.233371  0.932508  0.982700  0.344349  0.407924
#
#        rmse  rmse_log     log10     silog
# 0  2.486925  0.599047  0.244504  0.584481
# 1  1.319603  0.315749  0.115826  0.271402
# 2  2.092658  0.614045  0.260199  0.468917
# 3  1.551006  0.355016  0.145477  0.271742
# 4  1.255240  0.319730  0.126577  0.264007

# %%
print("Small model performance")
metrics[metrics.columns[1:]].mean()
# Out:
# Small model performance
# d1          0.279624
# d2          0.611704
# d3          0.884042
# abs_rel     0.489895
# sq_rel      0.795638
# rmse        1.720612
# rmse_log    0.419416
# log10       0.166812
# silog       0.343293
# dtype: float64

# %%
encoder = 'vitb' # or 'vits', 'vitb'
dataset = 'vkitti' # 'hypersim' for indoor model, 'vkitti' for outdoor model

model_base = DepthAnythingV2(**model_configs[encoder], max_depth=max_depth)
model_base.load_state_dict(
    torch.load(
        f"depth_anything_v2_metric_{dataset}_{encoder}.pth",
        map_location="cpu",
        weights_only=True,
    ),
)
model_base.to(DEVICE)
model_base.eval()
# Out:
# DepthAnythingV2(
#   (pretrained): DinoVisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#       (norm): Identity()
#     )
#     (blocks): ModuleList(
#       (0-11): 12 x NestedTensorBlock(
#         (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (attn): MemEffAttention(
#           (qkv): Linear(in_features=768, out_features=2304, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=768, out_features=768, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): LayerScale()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=768, out_features=3072, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=3072, out_features=768, bias=True)
# ...

# %%
metrics = evaluate_model(model_base, selection_dataset)
metrics.head()
# Out:
#   0%|          | 0/2768 [00:00<?, ?it/s]
#                  name        d1        d2        d3   abs_rel    sq_rel  \
# 0  00120-br-image.png  0.282939  0.602458  0.749892  0.545682  1.433185
# 1  00443-br-image.png  0.377174  0.984661  0.994152  0.293593  0.287257
# 2  00685-br-image.png  0.019964  0.089282  0.956531  0.731985  1.127322
# 3  00100-br-image.png  0.207818  0.988320  0.996727  0.321911  0.303521
# 4  00345-tr-image.png  0.077318  0.749481  0.975148  0.495294  0.709288
#
#        rmse  rmse_log     log10     silog
# 0  2.261958  0.479618  0.179822  0.424081
# 1  1.062242  0.289139  0.108397  0.239937
# 2  1.906686  0.558839  0.238221  0.427524
# 3  1.084076  0.287653  0.120196  0.219303
# 4  1.604709  0.417661  0.170451  0.317875

# %%
print("Base model performance")
metrics[metrics.columns[1:]].mean()
# Out:
# Base model performance
# d1          0.261386
# d2          0.612388
# d3          0.891222
# abs_rel     0.493463
# sq_rel      0.760128
# rmse        1.668134
# rmse_log    0.415438
# log10       0.167494
# silog       0.333004
# dtype: float64

# %%
encoder = 'vitl' # or 'vits', 'vitb'
dataset = 'vkitti' # 'hypersim' for indoor model, 'vkitti' for outdoor model

model_large = DepthAnythingV2(**model_configs[encoder], max_depth=max_depth)
model_large.load_state_dict(
    torch.load(
        f"depth_anything_v2_metric_{dataset}_{encoder}.pth",
        map_location="cpu",
        weights_only=True,
    ),
)
model_large.to(DEVICE)
model_large.eval()
# Out:
# DepthAnythingV2(
#   (pretrained): DinoVisionTransformer(
#     (patch_embed): PatchEmbed(
#       (proj): Conv2d(3, 1024, kernel_size=(14, 14), stride=(14, 14))
#       (norm): Identity()
#     )
#     (blocks): ModuleList(
#       (0-23): 24 x NestedTensorBlock(
#         (norm1): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (attn): MemEffAttention(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (attn_drop): Dropout(p=0.0, inplace=False)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (proj_drop): Dropout(p=0.0, inplace=False)
#         )
#         (ls1): LayerScale()
#         (drop_path1): Identity()
#         (norm2): LayerNorm((1024,), eps=1e-06, elementwise_affine=True)
#         (mlp): Mlp(
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (act): GELU(approximate='none')
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
# ...

# %%
metrics = evaluate_model(model_large, selection_dataset)
metrics.head()
# Out:
#   0%|          | 0/2768 [00:00<?, ?it/s]
#                  name        d1        d2        d3   abs_rel    sq_rel  \
# 0  00120-br-image.png  0.338454  0.435113  0.694880  0.599110  1.830593
# 1  00443-br-image.png  0.375281  0.981821  0.993677  0.300094  0.288214
# 2  00685-br-image.png  0.054595  0.080103  0.810907  0.788740  1.258349
# 3  00100-br-image.png  0.331899  0.997249  0.999272  0.274166  0.204649
# 4  00345-tr-image.png  0.042654  0.761111  0.967273  0.523558  0.846498
#
#        rmse  rmse_log     log10     silog
# 0  2.544777  0.517404  0.187781  0.441177
# 1  1.080404  0.285645  0.111366  0.229028
# 2  1.809531  0.591188  0.249685  0.442175
# 3  0.853334  0.252317  0.103991  0.191055
# 4  1.828574  0.430515  0.179583  0.318143

# %%
print("Large model performance")
metrics[metrics.columns[1:]].mean()
# Out:
# Large model performance
# d1          0.250841
# d2          0.612670
# d3          0.899621
# abs_rel     0.494874
# sq_rel      0.751132
# rmse        1.631825
# rmse_log    0.410614
# log10       0.167445
# silog       0.321587
# dtype: float64
